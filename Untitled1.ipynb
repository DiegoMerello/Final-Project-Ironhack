# %%
import datetime
import requests
from bs4 import BeautifulSoup
import re

# %%
names = []
prices = []
metals = requests.get('https://www.lme.com/').text
metals
# Out:
# '\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="en-GB" prefix="og: http://ogp.me/ns#">\r\n<head>\r\n    \r\n    <meta charset="utf-8" />\r\n    <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, shrink-to-fit=no" />\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1" />\r\n    <meta name="format-detection" content="telephone=no">\r\n\r\n    \r\n    \r\n<meta name="copyright" content="2022 The London Metal Exchange" />\r\n<meta name="author" content="The London Metal Exchange" />\r\n\r\n<title>Home | London Metal Exchange </title>\r\n\r\n    <link rel="canonical" href="https://www.lme.com/">\r\n\r\n<meta name="description" content="The world centre for industrial metals trading." />\r\n<meta name="robots" content="index,follow" />\r\n\r\n    <meta property="og:url" content="https://www.lme.com/" />\r\n\r\n\r\n\r\n    <link rel="alternate" href="https://www.lme.com/en/" hreflang="en" />\r\n\r\n<meta property="og:title" content="Home | London Metal Exchange " />\r\n<meta property="og:description" content="The world centre for industrial metals trading." />\r\n<meta property="og:locale" content="en" />\r\n<meta property="og:type" content="website" />\r\n<meta property="og:site_name" content="Lme" />\r\n\r\n\r\n<meta name="twitter:card" content="summary" />\r\n\r\n    <meta name="twitter:site" content="LME_news" />\r\n\r\n<meta name="twitter:title" content="Home | London Metal Exchange " />\r\n<meta name="twitter:description" content="The world centre for industrial metals trading." />\r\n\r\n\r\n\r\n    \r\n    \r\n\r\n\r\n\r\n<link rel="icon" type="image/x-icon" href="/favicon.ico" />\r\n\r\n\r\n\r\n\r\n\r\n    \r\n    <link href="/dist/css/styles.css?v=637847553640000000" rel="stylesheet">\r\n\r\n    \r\n\r\n    <script type="text/javascript">\r\n        !function (T, l, y) { var S = T.location, k = "script", D = "instrumentationKey", C = "ingestionendpoint", I = "disableExceptionTracking", E = "ai.device.", b = "toLowerCase", w = "crossOrigin", N = "POST", e = "appInsightsSDK", t = y.name || "appInsights"; (y.name || T[e]) && (T[e] = t); var n = T[t] || function (d) { var g = !1, f = !1, m = { initialize: !0, queue: [], sv: "5", version: 2, config: d }; function v(e, t) { var n = {}, a = "Browser"; return n[E + "id"] = a[b](), n[E + "type"] = a, n["ai.operation.name"] = S && S.pathname || "_unknown_", n["ai.internal.sdkVersion"] = "javascript:snippet_" + (m.sv || m.version), { time: function () { var e = new Date; function t(e) { var t = "" + e; return 1 === t.length && (t = "0" + t), t } return e.getUTCFullYear() + "-" + t(1 + e.getUTCMonth()) + "-" + t(e.getUTCDate()) + "T" + t(e.getUTCHours()) + ":" + t(e.getUTCMinutes()) + ":" + t(e.getUTCSeconds()) + "." + ((e.getUTCMilliseconds() / 1e3).toFixed(3) + "").slice(2, 5) + "Z" }(), iKey: e, name: "Microsoft.ApplicationInsights." + e.replace(/-/g, "") + "." + t, sampleRate: 100, tags: n, data: { baseData: { ver: 2 } } } } var h = d.url || y.src; if (h) { function a(e) { var t, n, a, i, r, o, s, c, u, p, l; g = !0, m.queue = [], f || (f = !0, t = h, s = function () { var e = {}, t = d.connectionString; if (t) for (var n = t.split(";"), a = 0; a < n.length; a++) { var i = n[a].split("="); 2 === i.length && (e[i[0][b]()] = i[1]) } if (!e[C]) { var r = e.endpointsuffix, o = r ? e.location : null; e[C] = "https://" + (o ? o + "." : "") + "dc." + (r || "services.visualstudio.com") } return e }(), c = s[D] || d[D] || "", u = s[C], p = u ? u + "/v2/track" : d.endpointUrl, (l = []).push((n = "SDK LOAD Failure: Failed to load Application Insights SDK script (See stack for details)", a = t, i = p, (o = (r = v(c, "Exception")).data).baseType = "ExceptionData", o.baseData.exceptions = [{ typeName: "SDKLoadFailed", message: n.replace(/\\./g, "-"), hasFullStack: !1, stack: n + "\\nSnippet failed to load [" + a + "] -- Telemetry is disabled\\nHelp Link: https://go.microsoft.com/fwlink/?linkid=2128109\\nHost: " + (S && S.pathname || "_unknow ...

# %%
soup = BeautifulSoup(metals, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-GB" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="2022 The London Metal Exchange" name="copyright"/>
# <meta content="The London Metal Exchange" name="author"/>
# <title>Home | London Metal Exchange </title>
# <link href="https://www.lme.com/" rel="canonical"/>
# <meta content="The world centre for industrial metals trading." name="description"/>
# <meta content="index,follow" name="robots"/>
# <meta content="https://www.lme.com/" property="og:url"/>
# <link href="https://www.lme.com/en/" hreflang="en" rel="alternate"/>
# <meta content="Home | London Metal Exchange " property="og:title"/>
# <meta content="The world centre for industrial metals trading." property="og:description"/>
# <meta content="en" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="Lme" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="LME_news" name="twitter:site"/>
# <meta content="Home | London Metal Exchange " name="twitter:title"/>
# <meta content="The world centre for industrial metals trading." name="twitter:description"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/dist/css/styles.css?v=637847553640000000" rel="stylesheet"/>
# <script type="text/javascript">
#         !function (T, l, y) { var S = T.location, k = "script", D = "instrumentationKey", C = "ingestionendpoint", I = "disableExceptionTracking", E = "ai.device.", b = "toLowerCase", w = "crossOrigin", N = "POST", e = "appInsightsSDK", t = y.name || "appInsights"; (y.name || T[e]) && (T[e] = t); var n = T[t] || function (d) { var g = !1, f = !1, m = { initialize: !0, queue: [], sv: "5", version: 2, config: d }; function v(e, t) { var n = {}, a = "Browser"; return n[E + "id"] = a[b](), n[E + "type"] = a, n["ai.operation.name"] = S && S.pathname || "_unknown_", n["ai.internal.sdkVersion"] = "javascript:snippet_" + (m.sv || m.version), { time: function () { var e = new Date; function t(e) { var t = "" + e; return 1 === t.length && (t = "0" + t), t } return e.getUTCFullYear() + "-" + t(1 + e.getUTCMonth()) + "-" + t(e.getUTCDate()) + "T" + t(e.getUTCHours()) + ":" + t(e.getUTCMinutes()) + ":" + t(e.getUTCSeconds()) + "." + ((e.getUTCMilliseconds() / 1e3).toFixed(3) + "").slice(2, 5) + "Z" }(), iKey: e, name: "Microsoft.ApplicationInsights." + e.replace(/-/g, "") + "." + t, sampleRate: 100, tags: n, data: { baseData: { ver: 2 } } } } var h = d.url || y.src; if (h) { function a(e) { var t, n, a, i, r, o, s, c, u, p, l; g = !0, m.queue = [], f || (f = !0, t = h, s = function () { var e = {}, t = d.connectionString; if (t) for (var n = t.split(";"), a = 0; a < n.length; a++) { var i = n[a].split("="); 2 === i.length && (e[i[0][b]()] = i[1]) } if (!e[C]) { var r = e.endpointsuffix, o = r ? e.location : null; e[C] = "https://" + (o ? o + "." : "") + "dc." + (r || "services.visualstudio.com") } return e }(), c = s[D] || d[D] || "", u = s[C], p = u ? u + "/v2/track" : d.endpointUrl, (l = []).push((n = "SDK LOAD Failure: Failed to load Application Insights SDK script (See stack for details)", a = t, i = p, (o = (r = v(c, "Exception")).data).baseType = "ExceptionData", o.baseData.exceptions = [{ typeName: "SDKLoadFailed", message: n.replace(/\./g, "-"), hasFullStack: !1, stack: n + "\nSnippet failed to load [" + a + "] -- Telemetry is disabled\nHelp Link: https://go.microsoft.com/fwlink/?linkid=2128109\nHost: " + (S && S.pathname || "_unknown_") + "\nEndpoint: " + i, parsedStack: [] }], r)), l.push(function (e, t, n, a) { var i = v(c, "Message"), r = i.data; r.baseType = "MessageData"; var o = r.baseData; return o.message = 'AI (Internal): 99 message:"' + ("SDK LOAD Failure: Failed to load Application Insights SDK script (See stack for details) (" + n + ")").replace(/\"/g, "") + '"', o.properties = { endpoint: a }, i }(0, 0, t, p)), function (e, t) { if (JSON) { var n = T.fetch; if (n && !y.useXhr) n(t, { method: N, body: JSON.stringify(e), mode: "cors" }); else if (XMLHttpRequest) { var a = new XMLHttpRequest; a.open(N, t), a.setRequestHeader("Content-type", "application/json"), a.send(JSON.stringify(e)) } } }(l, p)) } function i(e, t) { f || setTimeout(function () { !t && m.core || a() }, 500) } var e = function () { var n = l.createElement(k); n.src = h; var e = y[w]; return !e && "" !== e || "undefined" == n[w] || (n[w] = e), n.onload = i, n.onerror = a, n.onreadystatechange = function (e, t) { "loaded" !== n.readyState && "complete" !== n.readyState || i(0, t) }, n }(); y.ld < 0 ? l.getElementsByTagName("head")[0].appendChild(e) : setTimeout(function () { l.getElementsByTagName(k)[0].parentNode.appendChild(e) }, y.ld || 0) } try { m.cookie = l.cookie } catch (p) { } function t(e) { for (; e.length;)!function (t) { m[t] = function () { var e = arguments; g || m.queue.push(function () { m[t].apply(m, e) }) } }(e.pop()) } var n = "track", r = "TrackPage", o = "TrackEvent"; t([n + "Event", n + "PageView", n + "Exception", n + "Trace", n + "DependencyData", n + "Metric", n + "PageViewPerformance", "start" + r, "stop" + r, "start" + o, "stop" + o, "addTelemetryInitializer", "setAuthenticatedUserContext", "clearAuthenticatedUserContext", "flush"]), m.SeverityLevel = { Verbose: 0, Information: 1, Warning: 2, Error: 3, Critical: 4 }; var s = ( ...
#             src: "https://js.monitor.azure.com/scripts/b/ai.2.min.js", // The SDK URL Source
#             // name: "appInsights", // Global SDK Instance name defaults to "appInsights" when not supplied
#             // ld: 0, // Defines the load delay (in ms) before attempting to load the sdk. -1 = block page load and add to head. (default) = 0ms load after timeout,
#             // useXhr: 1, // Use XHR instead of fetch to report failures (if available),
#             crossOrigin: "anonymous", // When supplied this will add the provided value as the cross origin attribute on the script tag
#             // onInit: null, // Once the application insights instance has loaded and initialized this callback function will be called with 1 argument -- the sdk instance (DO NOT ADD anything to the sdk.queue -- As they won't get called)
#             cfg: { // Application Insights Configuration
#                 instrumentationKey: "de5f9630-c0b1-475f-bd73-b09bc5a749d7"
#                 /* ...Other Configuration Options... */
#             }
#         });
#     </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NBXWPZM');</script>
# <!-- End Google Tag Manager -->
# </head>
# <body data-main="main">
# <header class="header">
# <ul itemscope="" itemtype="http://www.schema.org/SiteNavigationElement" style="display: none">
# <li itemprop="name"><a href="https://www.lme.com/en/Company/About/Governance/LME-Clear-governance" itemprop="url">LME Clear Governance</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Trading/Contract-types" itemprop="url">Contract types</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Clearing" itemprop="url">Clearing</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Clearing/Collateral-management" itemprop="url">Collateral management</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Events" itemprop="url">Events</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Events/LME-Week" itemprop="url">LME Week</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Events/LME-Week/LME-Metals-Seminar" itemprop="url">LME Metals Seminar</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Company/About" itemprop="url">About</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Education" itemprop="url">LME Education</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Metals/Non-ferrous" itemprop="url">Non-ferrous metals</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Company/Legal" itemprop="url">Legal</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Trading/Access-the-market" itemprop="url">Access the market</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Trading" itemprop="url">Trading</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Trading/Trading-venues" itemprop="url">Trading venues</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Metals" itemprop="url">Metals</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Market-data/Accessing-market-data" itemprop="url">Accessing market data</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Trading/Systems" itemprop="url">Systems</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Market-data" itemprop="url">Market data    </a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Market-data/Reports-and-data" itemprop="url">Reports and data</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Market-data/Accessing-market-data/LMElive" itemprop="url">LMElive</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Market-data/Market-data-licensing" itemprop="url">Market data licensing</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Physical-services/Physical-market-benefits" itemprop="url">Physical market benefits</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Physical-services" itemprop="url">Physical services</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Physical-services/Warehousing" itemprop="url">Warehousing</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Clearing/Risk-management" itemprop="url">Risk management</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Metals/Ferrous" itemprop="url">Ferrous metals</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Metals/Precious" itemprop="url">Precious metals</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Metals/EV" itemprop="url">EV metals</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Clearing/Membership" itemprop="url">Membership</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Clearing/LME-Clear-projects" itemprop="url">LME Clear projects</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/CN" itemprop="url">CN home</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Clearing/How-LME-Clear-works" itemprop="url">How LME Clear works</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Company/Market-Regulation" itemprop="url">Market Regulation</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Education/Online-resources" itemprop="url">Online resources</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Education/Online-resources/Webinars" itemprop="url">Webinars</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Metals/Precious/LBMA-Platinum" itemprop="url">LBMA Platinum</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Metals/Precious/LBMA-Palladium" itemprop="url">LBMA Palladium</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Education/Course-calendar" itemprop="url">Course calendar</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Physical-services/Brands" itemprop="url">Brands</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/News" itemprop="url">News &amp; notices</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Market-data/LME-reference-prices" itemprop="url">LME reference prices</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Metals/EV/About-Lithium" itemprop="url">About Lithium</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Trading/Initiatives" itemprop="url">Initiatives</a></li>
# <li itemprop="name"><a href="https://www.lme.com/en/Clearing/Rules-and-regulations" itemprop="url">Rules and regulations</a></li>
# </ul>
# <img alt="LME Logo" class="printed-logo" height="46" loading="lazy" src="/-/media/Images/Logos/LME_Logo_Main.svg" width="99"/>
# <div class="meganav meganav--homepage" data-component="MegaNav" data-feature="Navigation">
# <mega-nav :is-homepage="true" inline-template="">
# <div :class="{
#           'meganav__inner--open': mobileNavOpen || openLevel1 != null,
#           'sticky-meganav': isSticky,
#           'meganav__inner--sticky-up': isScrollUp,
#         }" class="meganav__inner">
# <nav class="meganav__top" ref="desktopTop">
# <ul class="meganav__additional-links meganav__additional-links--tertiary">
# <li class="meganav__tertiary-link-item meganav__additional-link-item">
# <a class="meganav__tertiary-link meganav__additional-link" href="https://www.hkex.com.hk/">HKEX</a>
# </li>
# </ul>
# <ul class="meganav__additional-links meganav__additional-links--secondary">
# <li class="meganav__secondary-link-item meganav__additional-link-item">
# <a class="meganav__secondary-link meganav__additional-link" href="/en/News">News &amp; notices</a>
# </li>
# <li class="meganav__secondary-link-item meganav__additional-link-item">
# <a class="meganav__secondary-link meganav__additional-link" href="/en/Events">Events</a>
# </li>
# <li class="meganav__secondary-link-item meganav__additional-link-item">
# <a class="meganav__secondary-link meganav__additional-link" href="/en/Education">Education</a>
# </li>
# <li class="meganav__secondary-link-item meganav__additional-link-item">
# <a class="meganav__secondary-link meganav__additional-link" href="/en/Company/Contact-us">Contact us</a>
# </li>
# </ul>
# <account-cta :is-homepage="isHomepage" :is-logged-in="false" :is-nav-open="openLevel1 != null || isScrollUp" inline-template="">
# <div :class="{
#               'account-cta--loggedin': isLoggedIn,
#               'account-cta--homepage': isHomepage,
#               'account-cta--opennav': isNavOpen,
#               }" class="account-cta">
# <button :aria-expanded="isOpen ? 'true' : 'false'" class="account-cta__button" v-on:click="togglePanel">
# <svg aria-hidden="true" class="icon account-cta__button-icon" viewbox="0 0 12 14">
# <use xlink:href="/dist/icons/icons.svg#user"></use>
# </svg>
# <span class="account-cta__button-text account-cta__button-text--loggedout">
#                 Account
#             </span>
# <span class="account-cta__button-text account-cta__button-text--loggedin">
# </span>
# </button>
# <div class="account-cta__panel">
# <div class="account-cta__content account-cta__content--loggedout">
# <a class="account-cta__primary-link" data-redirect-url="" href="/en/Account/Login">Login</a>
# <span class="account-cta__secondary">
# <span class="account-cta__secondary-text">
#                         or
#                     </span>
# <a class="account-cta__secondary-link" href="/en/Account/Register">Register</a>
# </span>
# </div>
# <div class="account-cta__content account-cta__content--loggedin">
# <a class="account-cta__primary-link" href="/en/Account">Dashboard</a>
# <span class="account-cta__secondary">
# <a class="account-cta__link account-cta__secondary-link" data-redirect-url="" href="/en/Account/Logout?redirectTo=https://www.lme.com/Metals/Non-ferrous/LME-Aluminium">
#                         Log out
#                     </a>
# </span>
# </div>
# </div>
# </div>
# </account-cta>
# </nav>
# <div :class="{'meganav__main--sticky': isSticky}" :style="mainNavTopOffset" class="meganav__main">
# <div class="meganav__mobile-header" ref="mobileheader">
# <div class="meganav__button meganav__button--logo">
# <img alt="LME Logo" class="meganav__logo meganav__logo--white" height="49" src="/-/media/Images/Logos/LME_Logo_White.svg" width="105"/>
# <img alt="LME Logo" class="meganav__logo meganav__logo--color" height="49" loading="lazy" src="/-/media/Images/Logos/LME_Logo_Main.svg" width="105"/>
# </div>
# <search-button :is-mobile="isMobile" aria-controls="meganav-drawer" search-text="Search the LME">
# </search-button>
# <button :aria-expanded="mobileNavOpen ? 'true' : 'false'" aria-controls="meganav-drawer" class="meganav__button meganav__button--menu" v-if="isMobile" v-on:click="toggleMobileNav">
# <span class="meganav__button-text meganav__button-text--closed">
#                 Menu
#             </span>
# <span class="meganav__button-text meganav__button-text--open">
#                 Close
#             </span>
# </button>
# </div>
# <div :class="{'meganav__drawer--open': isMobile &amp;&amp; mobileNavOpen}" :style="drawerMobileStickyMaxHeightStyle" class="meganav__drawer" id="meganav-drawer" ref="drawer">
# <div class="meganav__desktop-left">
# <div class="meganav__button meganav__button--logo">
# <img alt="LME Logo" class="meganav__logo meganav__logo--white" height="49" src="/-/media/Images/Logos/LME_Logo_White.svg" width="105"/>
# <img alt="LME Logo" class="meganav__logo meganav__logo--color" height="49" loading="lazy" src="/-/media/Images/Logos/LME_Logo_Main.svg" width="105"/>
# </div>
# </div>
# <nav :class="{'meganav-primary-level--mobile-open': isMobile &amp;&amp; openLevel1 != null }" class="meganav-primary-level meganav__desktop-center">
# <div class="meganav-primary-level__search">
# <mobile-searchbar :is-open="mobileNavOpen" placeholder="type here" search-page-url="/en/Search" submit-text="Search">
# </mobile-searchbar>
# </div>
# <ul class="meganav-primary-level__list">
# <li :class="{'meganav-primary-level__item--open': openLevel1 === 0 }" class="meganav-primary-level__item meganav-4plus-style" data-primary-item="0">
# <button :aria-expanded="openLevel1 === 0 ? 'true' : 'false'" class="meganav-primary-level__button" v-on:click="toggleLevel1(0)">
#                     Metals
#                     <svg aria-hidden="true" class="icon meganav-primary-level__button-icon meganav-primary-level__button-icon--mobile" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon meganav-primary-level__button-icon--desktop" viewbox="0 0 14 7">
# <use xlink:href="/dist/icons/icons.svg#chevron-down"></use>
# </svg>
# </button>
# <div :class="{'meganav-primary-item--open': openLevel1 === 0 &amp;&amp; openLevel2 != null}" :style="primaryItemDesktopStickyMaxHeightStyle" class="meganav-primary-item">
# <ul class="meganav-primary-item__list">
# <li class="meganav-primary-item__primary-home">
# <button class="meganav-primary-item__back meganav__back" v-on:click="toggleLevel1(0)">
# <svg aria-hidden="true" class="icon meganav-primary-item__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav-primary-item__back-text">
#                                     Back
#                                 </span>
# </button>
# <a class="button-secondary meganav-primary-item__home-link" href="/en/Metals">Metals home</a>
# </li>
# <li :class="{'meganav-parent-item--first-click': isFirstClickIntoParentItem}" class="meganav-primary-item__col meganav-primary-item__col--links meganav-parent-item">
# <button :aria-expanded="openLevel1 === 0 &amp;&amp; openLevel2 === 0 ? 'true' : 'false'" class="meganav-parent-item__button" v-on:click="toggleLevel2(0)">
# <span class="meganav-parent-item__button-text">
#                                         Non-ferrous
#                                     </span>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# </button>
# <div class="meganav-parent-item__inner">
# <button class="meganav-parent-item__back meganav__back" v-on:click="toggleLevel2(0)">
# <svg aria-hidden="true" class="icon meganav__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav__back-text">
#                                             Back
#                                         </span>
# </button>
# <div class="meganav-parent-item__parent">
# <h2 class="meganav-parent-item__title">
# <a class="meganav-parent-item__parent-link" href="/en/Metals/Non-ferrous">All non-ferrous</a>
# </h2>
# <div class="meganav-parent-item__description">
#                                                 Non-ferrous prices discovered on our platforms are used as the global reference price.
#                                             </div>
# </div>
# <div class="meganav-parent-item__children">
# <h3 class="meganav-parent-item__children-title">
#                                                 Featured Links
#                                             </h3>
# <ul class="meganav-parent-item__children-list">
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Non-ferrous/LME-Aluminium" title="LME Aluminium">LME Aluminium</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Non-ferrous/LME-Copper" title="LME Copper">LME Copper</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Non-ferrous/LME-Zinc" title="LME Zinc">LME Zinc</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Non-ferrous/LME-Nickel" title="LME Nickel">LME Nickel</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Non-ferrous/LME-Lead" title="LME Lead">LME Lead</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Non-ferrous/LME-Tin" title="LME Tin">LME Tin</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Non-ferrous/LME-Aluminium-Alloy" title="LME Aluminium Alloy">LME Aluminium Alloy</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Non-ferrous/LME-NASAAC" title="LME NASAAC">LME NASAAC</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Non-ferrous/LME-Aluminium-premiums" title="LME Aluminium Premiums">LME Aluminium Premiums</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Non-ferrous/LME-Alumina_" title="LME Alumina (CRU/Fastmarkets MB)">LME Alumina (Platts)</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Non-ferrous/LME-Aluminium-UBC-Scrap-US-Argus">LME Aluminium UBC Scrap US (Argus)</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li :class="{'meganav-parent-item--first-click': isFirstClickIntoParentItem}" class="meganav-primary-item__col meganav-primary-item__col--links meganav-parent-item">
# <button :aria-expanded="openLevel1 === 0 &amp;&amp; openLevel2 === 1 ? 'true' : 'false'" class="meganav-parent-item__button" v-on:click="toggleLevel2(1)">
# <span class="meganav-parent-item__button-text">
#                                         Ferrous
#                                     </span>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# </button>
# <div class="meganav-parent-item__inner">
# <button class="meganav-parent-item__back meganav__back" v-on:click="toggleLevel2(1)">
# <svg aria-hidden="true" class="icon meganav__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav__back-text">
#                                             Back
#                                         </span>
# </button>
# <div class="meganav-parent-item__parent">
# <h2 class="meganav-parent-item__title">
# <a class="meganav-parent-item__parent-link" href="/en/Metals/Ferrous">All ferrous</a>
# </h2>
# <div class="meganav-parent-item__description">
# <span>Our ferrous contracts are tradable on LMEselect and via the inter-office market out to 15 months.</span>
# </div>
# </div>
# <div class="meganav-parent-item__children">
# <h3 class="meganav-parent-item__children-title">
#                                                 Featured Links
#                                             </h3>
# <ul class="meganav-parent-item__children-list">
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Ferrous/LME-Steel-Scrap-CFR-Turkey-Platts">LME Steel Scrap CFR Turkey (Platts)</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Ferrous/LME-Steel-Rebar-FOB-Turkey-Platts">LME Steel Rebar FOB Turkey (Platts)</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Ferrous/LME-Steel-HRC-FOB-China-Argus">LME Steel HRC FOB China (Argus)</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Ferrous/LME-Steel-HRC-N-America-Platts">LME Steel HRC N.America (Platts)</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Ferrous/LME-Steel-HRC-NW-Europe-Argus">LME Steel HRC NW Europe (Argus)</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Ferrous/LME-Steel-CFR-India-Platts">LME Steel Scrap CFR India (Platts)</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Ferrous/LME-Steel-CFR-Taiwan-Argus">LME Steel Scrap CFR Taiwan (Argus)</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li :class="{'meganav-parent-item--first-click': isFirstClickIntoParentItem}" class="meganav-primary-item__col meganav-primary-item__col--links meganav-parent-item">
# <button :aria-expanded="openLevel1 === 0 &amp;&amp; openLevel2 === 2 ? 'true' : 'false'" class="meganav-parent-item__button" v-on:click="toggleLevel2(2)">
# <span class="meganav-parent-item__button-text">
#                                         Precious
#                                     </span>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# </button>
# <div class="meganav-parent-item__inner">
# <button class="meganav-parent-item__back meganav__back" v-on:click="toggleLevel2(2)">
# <svg aria-hidden="true" class="icon meganav__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav__back-text">
#                                             Back
#                                         </span>
# </button>
# <div class="meganav-parent-item__parent">
# <h2 class="meganav-parent-item__title">
# <a class="meganav-parent-item__parent-link" href="/en/Metals/Precious">All precious</a>
# </h2>
# <div class="meganav-parent-item__description">
#                                                 LMEprecious is a collaborative initiative with the World Gold Council and a group of leading industry players.
#                                             </div>
# </div>
# <div class="meganav-parent-item__children">
# <h3 class="meganav-parent-item__children-title">
#                                                 Featured Links
#                                             </h3>
# <ul class="meganav-parent-item__children-list">
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Precious/LME-Gold" title="LME Gold">LME Gold</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Precious/LME-Silver" title="LME Silver">LME Silver</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Precious/LBMA-Platinum" title="LBMA Platinum">LBMA Platinum</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/Precious/LBMA-Palladium" title="LBMA Palladium">LBMA Palladium</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li :class="{'meganav-parent-item--first-click': isFirstClickIntoParentItem}" class="meganav-primary-item__col meganav-primary-item__col--links meganav-parent-item">
# <button :aria-expanded="openLevel1 === 0 &amp;&amp; openLevel2 === 3 ? 'true' : 'false'" class="meganav-parent-item__button" v-on:click="toggleLevel2(3)">
# <span class="meganav-parent-item__button-text">
#                                         EV
#                                     </span>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# </button>
# <div class="meganav-parent-item__inner">
# <button class="meganav-parent-item__back meganav__back" v-on:click="toggleLevel2(3)">
# <svg aria-hidden="true" class="icon meganav__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav__back-text">
#                                             Back
#                                         </span>
# </button>
# <div class="meganav-parent-item__parent">
# <h2 class="meganav-parent-item__title">
# <a class="meganav-parent-item__parent-link" href="/en/Metals/EV">All EV metals</a>
# </h2>
# <div class="meganav-parent-item__description">
#                                                 Our cash-settled contracts are tradable out to 15 months on LMEselect or the inter-office market.
#                                             </div>
# </div>
# <div class="meganav-parent-item__children">
# <h3 class="meganav-parent-item__children-title">
#                                                 Featured Links
#                                             </h3>
# <ul class="meganav-parent-item__children-list">
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/EV/LME-Cobalt" title="LME Cobalt">LME Cobalt</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/EV/LME-Cobalt-Fastmarkets-MB" title="LME Cobalt (Fastmarkets MB)">LME Cobalt (Fastmarkets MB)</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/EV/LME-Molybdenum-Platts" title="LME Molybdenum (Platts)">LME Molybdenum (Platts)</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/EV/LME-Lithium-Hydroxide-CIF-Fastmarkets-MB">LME Lithium Hydroxide CIF (Fastmarkets MB)</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/EV/About-Lithium" title="Lithium prices">Lithium prices</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="meganav-primary-item__col meganav-primary-item__col--promo">
# <aside class="meganav-promo-panel">
# <picture class="meganav-promo-panel__image">
# <source media="(min-width: 1024px)" srcset="/-/media/Images/James-test/Lithium-Cones.png?mh=700&amp;mw=700&amp;hash=8C75682BE70C408EDF5ADB84AB9FF58C">
# <source media="(min-width: 768px)" srcset="/-/media/Images/James-test/Lithium-Cones.png?mw=1024&amp;hash=B813E81C968D254F6FFDB9674B7020D9">
# <img alt="Lithium Cones" loading="lazy" src="/-/media/Images/James-test/Lithium-Cones.png?mw=700&amp;hash=05BDACB560F82059685DF1F5235592C7"/>
# </source></source></picture>
# <a class="meganav-promo-panel__link" haschildren="True" href="/en/Metals/EV/About-Lithium" title="Lithium/EV"> <span class="meganav-promo-panel__link-text">
#                                                 Find out more about our new battery-grade lithium hydroxide futures contract.
#                                             </span>
# <span aria-hidden="true" class="meganav-promo-panel__link-icon"></span>
# </a> </aside>
# </li>
# </ul>
# </div>
# </li>
# <li :class="{'meganav-primary-level__item--open': openLevel1 === 1 }" class="meganav-primary-level__item meganav-4plus-style" data-primary-item="1">
# <button :aria-expanded="openLevel1 === 1 ? 'true' : 'false'" class="meganav-primary-level__button" v-on:click="toggleLevel1(1)">
#                     Trading
#                     <svg aria-hidden="true" class="icon meganav-primary-level__button-icon meganav-primary-level__button-icon--mobile" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon meganav-primary-level__button-icon--desktop" viewbox="0 0 14 7">
# <use xlink:href="/dist/icons/icons.svg#chevron-down"></use>
# </svg>
# </button>
# <div :class="{'meganav-primary-item--open': openLevel1 === 1 &amp;&amp; openLevel2 != null}" :style="primaryItemDesktopStickyMaxHeightStyle" class="meganav-primary-item">
# <ul class="meganav-primary-item__list">
# <li class="meganav-primary-item__primary-home">
# <button class="meganav-primary-item__back meganav__back" v-on:click="toggleLevel1(1)">
# <svg aria-hidden="true" class="icon meganav-primary-item__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav-primary-item__back-text">
#                                     Back
#                                 </span>
# </button>
# <a class="button-secondary meganav-primary-item__home-link" href="/en/Trading">Trading home</a>
# </li>
# <li :class="{'meganav-parent-item--first-click': isFirstClickIntoParentItem}" class="meganav-primary-item__col meganav-primary-item__col--links meganav-parent-item">
# <button :aria-expanded="openLevel1 === 1 &amp;&amp; openLevel2 === 0 ? 'true' : 'false'" class="meganav-parent-item__button" v-on:click="toggleLevel2(0)">
# <span class="meganav-parent-item__button-text">
#                                         Access the market
#                                     </span>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# </button>
# <div class="meganav-parent-item__inner">
# <button class="meganav-parent-item__back meganav__back" v-on:click="toggleLevel2(0)">
# <svg aria-hidden="true" class="icon meganav__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav__back-text">
#                                             Back
#                                         </span>
# </button>
# <div class="meganav-parent-item__parent">
# <h2 class="meganav-parent-item__title">
# <a class="meganav-parent-item__parent-link" href="/en/Trading/Access-the-market">Access the market</a>
# </h2>
# <div class="meganav-parent-item__description">
#                                                 Whether you are an industrial hedger, physical market trader or prop desk there are, broadly speaking, two ways of accessing our markets.
#                                             </div>
# </div>
# <div class="meganav-parent-item__children">
# <h3 class="meganav-parent-item__children-title">
#                                                 Featured Links
#                                             </h3>
# <ul class="meganav-parent-item__children-list">
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Access-the-market/Find-a-member" title="Find a member">Find a member</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Access-the-market/Become-a-member" title="Become a member">Become a member</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Access-the-market/ISVs-and-connectivity-providers" title="ISVs and connectivity providers">ISVs and connectivity providers</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Access-the-market/Incentive-programmes" title="Incentive programs">Incentive programmes</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Access-the-market/Fees">Fees</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li :class="{'meganav-parent-item--first-click': isFirstClickIntoParentItem}" class="meganav-primary-item__col meganav-primary-item__col--links meganav-parent-item">
# <button :aria-expanded="openLevel1 === 1 &amp;&amp; openLevel2 === 1 ? 'true' : 'false'" class="meganav-parent-item__button" v-on:click="toggleLevel2(1)">
# <span class="meganav-parent-item__button-text">
#                                         Trading venues
#                                     </span>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# </button>
# <div class="meganav-parent-item__inner">
# <button class="meganav-parent-item__back meganav__back" v-on:click="toggleLevel2(1)">
# <svg aria-hidden="true" class="icon meganav__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav__back-text">
#                                             Back
#                                         </span>
# </button>
# <div class="meganav-parent-item__parent">
# <h2 class="meganav-parent-item__title">
# <a class="meganav-parent-item__parent-link" href="/en/Trading/Trading-venues">Trading venues</a>
# </h2>
# <div class="meganav-parent-item__description">
#                                                 The LME provides the market with three transparent and regulated platforms for trading industrial metal contracts.
#                                             </div>
# </div>
# <div class="meganav-parent-item__children">
# <h3 class="meganav-parent-item__children-title">
#                                                 Featured Links
#                                             </h3>
# <ul class="meganav-parent-item__children-list">
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Trading-venues/The-Ring" title="The Ring">The Ring</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Trading-venues/Electronic" title="Electronic">Electronic</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Trading-venues/Telephone" title="Telephone">Telephone</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Trading-venues/Trading-times" title="Trading times">Trading times</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li :class="{'meganav-parent-item--first-click': isFirstClickIntoParentItem}" class="meganav-primary-item__col meganav-primary-item__col--links meganav-parent-item">
# <button :aria-expanded="openLevel1 === 1 &amp;&amp; openLevel2 === 2 ? 'true' : 'false'" class="meganav-parent-item__button" v-on:click="toggleLevel2(2)">
# <span class="meganav-parent-item__button-text">
#                                         LME systems
#                                     </span>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# </button>
# <div class="meganav-parent-item__inner">
# <button class="meganav-parent-item__back meganav__back" v-on:click="toggleLevel2(2)">
# <svg aria-hidden="true" class="icon meganav__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav__back-text">
#                                             Back
#                                         </span>
# </button>
# <div class="meganav-parent-item__parent">
# <h2 class="meganav-parent-item__title">
# <a class="meganav-parent-item__parent-link" href="/en/Trading/Systems">LME systems</a>
# </h2>
# <div class="meganav-parent-item__description">
#                                                 A set of robust systems and technologies underpin trading at the LME.
#                                             </div>
# </div>
# <div class="meganav-parent-item__children">
# <h3 class="meganav-parent-item__children-title">
#                                                 Featured Links
#                                             </h3>
# <ul class="meganav-parent-item__children-list">
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Systems/LMEselect" title="LMEselect">LMEselect</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Systems/LMEsmart" title="LMEsmart">LMEsmart</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Systems/LMEsword" title="LMEsword">LMEsword</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Systems/LMEmercury" title="LMEmercury">LMEmercury</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li :class="{'meganav-parent-item--first-click': isFirstClickIntoParentItem}" class="meganav-primary-item__col meganav-primary-item__col--links meganav-parent-item">
# <button :aria-expanded="openLevel1 === 1 &amp;&amp; openLevel2 === 3 ? 'true' : 'false'" class="meganav-parent-item__button" v-on:click="toggleLevel2(3)">
# <span class="meganav-parent-item__button-text">
#                                         Contract types
#                                     </span>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# </button>
# <div class="meganav-parent-item__inner">
# <button class="meganav-parent-item__back meganav__back" v-on:click="toggleLevel2(3)">
# <svg aria-hidden="true" class="icon meganav__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav__back-text">
#                                             Back
#                                         </span>
# </button>
# <div class="meganav-parent-item__parent">
# <h2 class="meganav-parent-item__title">
# <a class="meganav-parent-item__parent-link" href="/en/Trading/Contract-types">Contract types</a>
# </h2>
# <div class="meganav-parent-item__description">
# <span>Our contracts allow all those along the metal supply chain, as well as investment communities, to hedge against or take on price risk.</span>
# </div>
# </div>
# <div class="meganav-parent-item__children">
# <h3 class="meganav-parent-item__children-title">
#                                                 Featured Links
#                                             </h3>
# <ul class="meganav-parent-item__children-list">
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Contract-types/Futures" title="Futures">Futures</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Contract-types/Options" title="Options">Options</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Contract-types/Trade-at-settlement" title="Trade at settlement">Trade at settlement</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Contract-types/TAPOS" title="TAPOS">TAPOS</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Contract-types/Monthly-Average-Futures" title="Monthly average futures">Monthly average futures</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Contract-types/HKEX-London-Minis" title="HKEX-London Minis">HKEX-London Minis</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Contract-types/LMEminis" title="LMEminis">LMEminis</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li :class="{'meganav-parent-item--first-click': isFirstClickIntoParentItem}" class="meganav-primary-item__col meganav-primary-item__col--links meganav-parent-item">
# <button :aria-expanded="openLevel1 === 1 &amp;&amp; openLevel2 === 4 ? 'true' : 'false'" class="meganav-parent-item__button" v-on:click="toggleLevel2(4)">
# <span class="meganav-parent-item__button-text">
#                                         Initiatives
#                                     </span>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# </button>
# <div class="meganav-parent-item__inner">
# <button class="meganav-parent-item__back meganav__back" v-on:click="toggleLevel2(4)">
# <svg aria-hidden="true" class="icon meganav__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav__back-text">
#                                             Back
#                                         </span>
# </button>
# <div class="meganav-parent-item__parent">
# <h2 class="meganav-parent-item__title">
# <a class="meganav-parent-item__parent-link" href="/en/Trading/Initiatives">Initiatives</a>
# </h2>
# <div class="meganav-parent-item__description">
#                                                 Find out more about our latest offerings
#                                             </div>
# </div>
# <div class="meganav-parent-item__children">
# <h3 class="meganav-parent-item__children-title">
#                                                 Featured links
#                                             </h3>
# <ul class="meganav-parent-item__children-list">
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Initiatives/Market-structure-evolution">Market structure evolution</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Initiatives/New-trading-platform">New trading platform</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href=""></a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Company/Responsibility/Sustainability">Sustainability</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Initiatives/LMEpassport">LMEpassport</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Trading/Initiatives/Metalshub-collaboration">Metalshub collaboration</a>
# </li>
# <li class="meganav-parent-item__child">
# <a class="meganav-parent-item__child-link" href="/en/Metals/EV">EV metals</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li :class="{'meganav-parent-item--first-click': isFirstClickIntoParentItem}" class="meganav-primary-item__col meganav-primary-item__col--links meganav-parent-item">
# <button :aria-expanded="openLevel1 === 1 &amp;&amp; openLevel2 === 5 ? 'true' : 'false'" class="meganav-parent-item__button" v-on:click="toggleLevel2(5)">
# <span class="meganav-parent-item__button-text">
#                                         Rulebook and notices
#                                     </span>
# <svg aria-hidden="true" class="icon meganav-primary-level__button-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# </button>
# <div class="meganav-parent-item__inner">
# <button class="meganav-parent-item__back meganav__back" v-on:click="toggleLevel2(5)">
# <svg aria-hidden="true" class="icon meganav__back-icon" viewbox="0 0 8 14">
# <use xlink:href="/dist/icons/icons.svg#chevron"></use>
# </svg>
# <span class="meganav__back-text">
#                                             Back
#                                         </span>
# </button>
# <div class="meganav-parent-item__parent">
# <h2 class="meganav-parent-item__title">
# <a class="meganav-parent-item__parent-link" href="/en/Company/Market-Regulation/Rules">Rulebook and notices</a>
# </h2>
# <div class="meganav-parent-item__description">
#                                                 The LME Rulebook sets out the rules and regulations of the London Metal Exchange.<br/>
# <br/>
# </div>
# </div>
# </div>
# </li>
# <li class="meganav-primary-item__col meganav-primary-item__col--promo">
# <aside class="meganav-promo-panel">
# <picture class="meganav-promo-panel__image">
# ...
#                     </div>
# <span class="cta-block__column-btn"></span>
# </div>
# </div>
# </div>
# </a>
# <a class="cta-block__column-link cta-block__column-outer" href="/Market-data/Reports-and-data"> <div class="cta-block__column-item">
# <div class="cta-block__column-icon">
# <img alt="speech-bubble-white" class="icon" loading="lazy" src="/-/media/Images/Icons/speech-bubble-white.svg?la=en&amp;hash=DC30D6BC1CA6FB741CAAF889507CF0D1" title="$name"/>
# </div>
# <div class="cta-block__column-content">
# <div class="cta-block__column-text">
# <img alt="speech-bubble-white" class="icon cta-block__mobile-icon" loading="lazy" src="/-/media/Images/Icons/speech-bubble-white.svg?la=en&amp;hash=DC30D6BC1CA6FB741CAAF889507CF0D1" title="$name"/>
# <h5 class="cta-block__column-title">
#                         Reports on LME.com
#                     </h5>
# <div class="cta-block__column-time">
# </div>
# </div>
# <div class="cta-block__column-info">
# <div class="cta-block__column-description">
#                         From average prices and stock movements to warrant banding and the commitment of traders - we publish a number of reports, summarised here.
#                     </div>
# <span class="cta-block__column-btn"></span>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# </div>
# <div class="image-promo-panel">
# <div class="image-promo-panel__logo">
# <div class="image-promo-panel__logo-wrapper">
# <img alt="LMEpassport" class="image-promo-panel__logo-img" loading="lazy" src="/-/media/Images/400x/LMEpassport.PNG?la=en&amp;h=70&amp;w=180&amp;mw=180&amp;hash=899B89B0F02880DCE9B88DA1618D6822" title="LMEpassport"/>
# </div>
# <img alt="" class="image-promo-panel__logo-form" height="87" loading="lazy" src="/dist/images/LME_Shapes_Red.svg" width="88"/>
# </div>
# <div class="image-promo-panel__content">
# <div class="image-promo-panel__content-description">
# <p class="image-promo-panel__content-description-paragraph"><strong>LMEpassport</strong>, a key component of the LME’s drive for a more sustainable future, is a new system that does away with paper certificates of analysis and provides the market with a new voluntary register of a metal’s sustainability credentials. </p>
# <a class="button-primary" href="/Trading/Initiatives/LMEpassport">Find out more</a>
# </div>
# <img alt="" class="image-promo-panel__content-form" height="65" loading="lazy" src="/dist/images/LME_Shapes_Blue.svg" width="223"/>
# </div>
# </div>
# <div class="full-width-promo-panel bg-image" data-lazy="" data-src="/-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=100&amp;hash=2FDB300B36FD35C7EE1FDB2DB9E1015D, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=200&amp;hash=1F84F403A155CB58919A530FBFC95CF7, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=300&amp;hash=5547D7DBD426A1082A5697152B9D6199, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=400&amp;hash=532E404D504BF79BFFE7D085F2B6E12D, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=500&amp;hash=DCA028A89D04A4B5BA5DCFF5F6435A8C, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=600&amp;hash=9F7CFF13CBB37A106726174F6AA064D6, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=700&amp;hash=83D31D807023E10DE8D77C28FE4002A2, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=800&amp;hash=3A54963F94E13EA006AF94D07A03E95D, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=900&amp;hash=28EBD2460A076619B16765C22328DC55, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=1000&amp;hash=8BFC945EFFB1DEB557D79462B0B69B4F, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=1100&amp;hash=FC1992B310AFD2F0743F62309992F6E5, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=1200&amp;hash=B5E9DFA0C7C2C8F495F444FC7914B6FC, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=1300&amp;hash=804CFFF6B9D5E2510C45F3E2F41C7E25, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=1400&amp;hash=F9EF6230F7B155DAB6F79BA750FAD88E, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=1500&amp;hash=9FC30F8D77ACB61A4C48CA62FC20E1FF, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=1600&amp;hash=8025B7FEB3EC7F7E301D020A13A90258, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=1700&amp;hash=9D2C9E201621D77F27A0F45C4F9B6458, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=1800&amp;hash=CCCCBC25532795F2A725CCD7B0E2B735, /-/media/Images/James-test/Manufacturing_Sparks_MONO_1900.jpg?w=1900&amp;hash=FAABAE1854AC3AFABE9203118E422C90">
# <div class="full-width-promo-panel__inner">
# <div class="full-width-promo-panel__subtitle">
#             Stay up to date
#         </div>
# <h2 class="full-width-promo-panel__title">
# <strong>Register</strong> with LME.com
#         </h2>
# <div class="full-width-promo-panel__copy">
#             Receive full access to all our price data and gain access to our monthly LME newsletter, packed with market tips and insights from our on-staff specialists.
#         </div>
# <div class="full-width-promo-panel__cta-wrapper">
# <a class="button-primary" href="/en/Account/Register">Register now</a>
# </div>
# </div>
# </div>
# </div>
# </main>
# <footer class="footer footer--full-cols">
# <div class="footer__row footer__row--main">
# <div class="footer__col footer__col--primary">
# <ul class="footer__link-list footer__link-list--large">
# <li class="footer__link-list-item footer__link-list-item--large">
# <a class="footer__link" href="/en/Metals">Metals</a> </li>
# <li class="footer__link-list-item footer__link-list-item--large">
# <a class="footer__link" href="/en/Trading">Trading</a> </li>
# <li class="footer__link-list-item footer__link-list-item--large">
# <a class="footer__link" href="/en/Clearing">Clearing</a> </li>
# <li class="footer__link-list-item footer__link-list-item--large">
# <a class="footer__link" href="/en/Market-data">Market data</a> </li>
# <li class="footer__link-list-item footer__link-list-item--large">
# <a class="footer__link" href="/en/Physical-services">Physical services</a> </li>
# </ul>
# </div>
# <div class="footer__col">
# <h4 class="footer__header">About</h4>
# <ul class="footer__link-list">
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/About" title="About us">                            About the LME
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/About/Committees" title="Committees">                            Committees
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/About/Governance" title="LME Clear Ltd">                            Governance
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/About/Corporate" title="LME Holdings and share structure">                            Corporate
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/About/Business-continuity" title="Business Continuity">                            Business continuity
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/About/FAQs" title="FAQs">                            FAQs
# </a> </li>
# </ul>
# </div>
# <div class="footer__col">
# <h4 class="footer__header">Regulation</h4>
# <ul class="footer__link-list">
# <li class="footer__link-list-item">
# <a class="footer__link" href="/-/media/Files/Company/Market-regulation/Rulebook/LME-Rulebook-March-22.pdf" title="LME rulebook">                            LME Rulebook
#                                 <span class="footer__link-download">(Download)</span>
# <svg aria-hidden="true" class="icon" viewbox="0 0 24 24">
# <use xlink:href="/dist/icons/icons.svg#download"></use>
# </svg>
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/-/media/Files/Clearing/Rules-and-regulations/LME-Clear-rules-and-procedures-July-2021.pdf" title="LME Clear rulebook">                            LME Clear Rulebook
#                                 <span class="footer__link-download">(Download)</span>
# <svg aria-hidden="true" class="icon" viewbox="0 0 24 24">
# <use xlink:href="/dist/icons/icons.svg#download"></use>
# </svg>
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/-/media/Files/Company/Market-regulation/Guide-to-the-LME-December-2020.pdf">                            Guide to market structure
#                                 <span class="footer__link-download">(Download)</span>
# <svg aria-hidden="true" class="icon" viewbox="0 0 24 24">
# <use xlink:href="/dist/icons/icons.svg#download"></use>
# </svg>
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Market-Regulation">                            Market regulation
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Market-Regulation/Benchmark-regulation" title="European Benchmark regulation">                            Benchmark regulation
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Market-Regulation/Pre-trade-transparency" title="MiFID II">                            Pre-trade transparency
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Market-Regulation/Brexit" title="Brexit">                            Brexit
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Market-Regulation/Rules">                            Rules
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Market-Regulation/Arbitration" title="Arbitration">                            Arbitration
# </a> </li>
# </ul>
# </div>
# <div class="footer__col">
# <h4 class="footer__header">Responsibility</h4>
# <ul class="footer__link-list">
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Responsibility/Responsible-sourcing">                            Responsible sourcing
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Responsibility/Sustainability">                            Sustainability
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Responsibility/Conduct">                            Conduct
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Responsibility/Diversity-and-inclusion">                            Diversity and inclusion
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Responsibility/Charity">                            Charity
# </a> </li>
# <li class="footer__link-list-item">
# <a class="footer__link" href="/en/Company/Responsibility/Corporate-disclosure">                            Corporate disclosure
# </a> </li>
# </ul>
# </div>
# <div class="footer__col footer__col--contact">
# <h4 class="footer__small-header">Contact Us</h4>
# <ul class="footer__link-list footer__link-list--contact">
# <li class="footer-location">
# <h5 class="footer-location__header">London</h5>
# <address class="footer-location__content">
# <a class="footer-location__phone" href="tel:+44 (0)207113 8888">+44 (0)207113 8888</a>
# <div class="footer-location__address">
# <a href="https://www.google.com/maps/place/The+London+Metal+Exchange/@51.5212767,-0.0878272,18z/data=!4m13!1m7!3m6!1s0x48761caeb1aad1db:0xd136380926d8c84!2s10+Finsbury+Square,+Finsbury,+London+EC2A+1AJ,+UK!3b1!8m2!3d51.5213885!4d-0.0875101!3m4!1s0x4876034ce3a59597:0xc39b49dee8e3f602!8m2!3d51.521121!4d-0.0875433"><p>10 Finsbury Square<br/>
# London<br/>
# EC2A 1AJ</p></a> </div>
# </address>
# </li>
# <li class="footer-location">
# <h5 class="footer-location__header">Singapore</h5>
# <address class="footer-location__content">
# <a class="footer-location__phone" href="tel:+65 6535 5035">+65 6535 5035</a>
# <div class="footer-location__address">
# <a href="https://www.google.com/maps/place/MYP+Centre/@1.2852303,103.8512534,17.75z/data=!4m6!3m5!1s0x31da190939163be1:0x1cc3035724865e64!4b1!8m2!3d1.2851228!4d103.8523753"><p>9 Battery Road<br/>
# #07-02<br/>
# MYP Centre<br/>
# Raffles Place<br/>
# Singapore<br/>
# 049910</p></a> </div>
# </address>
# </li>
# </ul>
# </div>
# </div>
# <div class="footer__row footer__row--connection">
# <div class="footer__social">
# <ul class="footer__social-list">
# <li class="footer-social-link">
# <a class="button-round-alt" href="https://www.linkedin.com/company/london-metal-exchange/" rel="noopener noreferrer" target="_blank"> <span class="footer-social-link__text"></span>
# <img alt="linkedIn" class="icon" loading="lazy" src="/-/media/Images/Icons/LinkedIn.png?h=140&amp;w=140&amp;la=en&amp;hash=76FC82F58CA068F78EC700F94490E21C" title="Linkedin"/></a> </li>
# <li class="footer-social-link">
# <a class="button-round-alt" href="https://twitter.com/LME_news" rel="noopener noreferrer" target="_blank"> <span class="footer-social-link__text"></span>
# <img alt="twitter" class="icon" loading="lazy" src="/-/media/Images/Icons/Twitter.png?h=140&amp;w=140&amp;la=en&amp;hash=CEB1B7EF0EB183305C2B666D4FA698D8" title="Twitter"/></a> </li>
# <li class="footer-social-link">
# <a class="button-round-alt" href="https://vimeo.com/londonmetalexchange" rel="noopener noreferrer" target="_blank"> <span class="footer-social-link__text"></span>
# <img alt="vimeo" class="icon" loading="lazy" src="/-/media/Images/Icons/Vimeo.png?h=140&amp;w=140&amp;la=en&amp;hash=CDBE1335D53E19CEEA3A6AC5E1CC3702" title="Vimeo"/></a> </li>
# <li class="footer-social-link">
# <a class="button-round-alt" href="https://www.hkex.com.hk/eng/newsconsul/qrcode.htm" rel="noopener noreferrer" target="_blank"> <span class="footer-social-link__text"></span>
# <img alt="WeChat" class="icon" loading="lazy" src="/-/media/Images/Icons/WeChat.png?h=140&amp;w=140&amp;la=en&amp;hash=2FABFBD374BF0F31A14111E2253F3460" title="WeChat"/></a> </li>
# </ul>
# </div>
# <div class="footer__signup">
# <a class="footer__signup-button button-secondary-alt" href="/Account/Register">Register</a>
# <a class="footer__signup-button button-primary-alt" href="/Account/Login">Log in</a>
# </div>
# </div>
# <div class="footer__row footer__row--legal">
# <div class="footer__legal-inner">
# <ul class="footer__link-list footer__link-list--legal">
# <li class="footer__link-list-item footer__link-list-item--legal">
# <a class="footer__link" href="/en/Company/Legal">Legal</a>
# </li>
# <li class="footer__link-list-item footer__link-list-item--legal">
# <a class="footer__link" href="/en/Company/Legal/Privacy-statement">Privacy statement</a>
# </li>
# <li class="footer__link-list-item footer__link-list-item--legal">
# <a class="footer__link" href="/en/Company/Legal/Cookie-policy">Cookie policy</a>
# </li>
# <li class="footer__link-list-item footer__link-list-item--legal">
# <a class="footer__link" href="/en/Company/Legal/Website-terms-and-conditions">Website T&amp;C's</a>
# </li>
# <li class="footer__link-list-item footer__link-list-item--legal">
# <a class="footer__link" href="/en/Company/Responsibility/Corporate-disclosure">Modern slavery statement</a>
# </li>
# <li class="footer__link-list-item footer__link-list-item--legal">
# <a class="footer__link" href="/en/Company/Legal/russian-sanctions">Russian Sanctions</a>
# </li>
# <li class="footer__link-list-item footer__link-list-item--legal">
# <a class="footer__link" href="/en/Company/Cyber-security-awareness">Cyber security awareness</a>
# </li>
# <li class="footer__link-list-item footer__link-list-item--legal">
# <a class="footer__link" href="/en/Company/Suspicious-websites">Suspicious websites</a>
# </li>
# </ul>
# <div class="footer__copyright-text">© 2022 The London Metal Exchange - an <a href="http://hkex.com.hk" rel="noopener noreferrer" target="_blank">HKEX</a> Company. All rights reserved.
#     </div>
# </div>
# </div>
# </footer>
# <script async="" defer="" src="/dist/js/app.js?v=637847553780000000"></script>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NBXWPZM" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div id="modals"></div>
# </body>
# </html>

# %%
metal_table = soup.find("table", attrs={"class": "ring-times"})
metal_table

# %%
metal_table_names, metal_table_prices = metal_table.tbody.find_all("th"), metal_table.tbody.find_all("td")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4460\1382121892.py in <module>
# ----> 1 metal_table_names, metal_table_prices = metal_table.tbody.find_all("th"), metal_table.tbody.find_all("td")
#
# AttributeError: 'NoneType' object has no attribute 'tbody'
