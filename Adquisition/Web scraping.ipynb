# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url='https://www.dailymetalprice.com/'

# %%
html_response = requests.get(url).content
soup = BeautifulSoup(html_response, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="initial-scale=1.0 width=device-width" name="viewport"/>
# <title>Daily Metal Price: Free Metal Price Tables and Charts</title>
# <meta content="Free Metal Price Tables and Charts Updated Daily: Latest metal prices and charts by date and currency." name="description">
# <link href="https://www.dailymetalprice.com" rel="canonical"/>
# <link href="/A.css,,_bootstrap.min.css+font-awesome,,_css,,_font-awesome.min.css+css,,_custom.css+css,,_theme.css,Mcc.8LHq7vlYUV.css.pagespeed.cf.0zq70VA9ut.css" rel="stylesheet"/>
# <script async="" data-ad-client="ca-pub-9456108336672156" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# </meta></head>
# <body>
# <!-- Header -->
# <header>
# <nav class="navbar navbar-inverse" role="navigation">
# <div class="container-fluid" style="padding-top: 3px;">
# <div class="navbar-header">
# <a class="navbar-brand" href="/">
# <i aria-hidden="true" class="fa fa-area-chart"></i>
# <strong>Daily Metal Prices</strong>
# </a>
# <!-- Mobile toggle nav button -->
# <button class="navbar-toggle collapsed" data-target="#header-nav" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <!-- Collapsible Nav links -->
# <div class="collapse navbar-collapse" id="header-nav">
# <ul class="nav navbar-nav">
# <li><a href="/metalprices.php"><i class="fa fa-globe"></i> Daily Spot Prices</a></li>
# <li><a href="/metalpricecharts.php"><i class="fa fa-line-chart"></i> Metal Price Charts</a></li>
# <li><a href="/metaltables.php"><i class="fa fa-calendar"></i> Prices by Date</a></li>
# <li><a href="/metalpricescurr.php"><i class="fa fa-calculator"></i> Prices by Currency</a></li>
# <li><a href="/archive.php"><i class="fa fa-archive"></i> Archive</a></li>
# </ul>
# </div>
# <!-- /.navbar-collapse -->
# </div>
# <!-- /.container-fluid -->
# </nav>
# </header>
# <!-- End Header --><!-- Main content area -->
# <div class="container">
# <div class="row">
# <div class="col-sm-3 col-md-3 col-lg-4">
# <div class="panel panel-success">
# <div class="panel-heading"><h2 class="panel-title"><i class="fa fa-globe"></i> <strong>Popular Metal Prices</strong>
# </h2></div>
# <div class="panel-body"><table class="table table-striped success table-hover table-condensed">
# <thead><tr><th>Metal</th><th>Price</th><th class="hidden-sm hidden-md">Date</th></tr></thead>
# <tbody><tr><td><a href="aluminum.html">Aluminum</a></td><td>$1.4039 <span class="hidden-sm hidden-md">lb</span></td><td class="hidden-sm hidden-md">Apr 25, 2022</td></tr><tr><td><a href="cobalt.html">Cobalt</a></td><td>$37.195 <span class="hidden-sm hidden-md">lb</span></td><td class="hidden-sm hidden-md">Apr 22, 2022</td></tr><tr><td><a href="copper.html">Copper</a></td><td>$4.4455 <span class="hidden-sm hidden-md">lb</span></td><td class="hidden-sm hidden-md">Apr 25, 2022</td></tr><tr><td><a href="gold.html">Gold</a></td><td>$1897.46 <span class="hidden-sm hidden-md">oz</span></td><td class="hidden-sm hidden-md">Apr 25, 2022</td></tr><tr><td><a href="iron-ore.html">Iron Ore</a></td><td>$152.47 <span class="hidden-sm hidden-md">mt</span></td><td class="hidden-sm hidden-md">Apr 25, 2022</td></tr><tr><td><a href="lead.html">Lead</a></td><td>$1.0836 <span class="hidden-sm hidden-md">lb</span></td><td class="hidden-sm hidden-md">Apr 22, 2022</td></tr><tr><td><a href="lithium.html">Lithium</a></td><td>$73.209 <span class="hidden-sm hidden-md">kg</span></td><td class="hidden-sm hidden-md">Apr 25, 2022</td></tr><tr><td><a href="nickel.html">Nickel</a></td><td>$15.000 <span class="hidden-sm hidden-md">lb</span></td><td class="hidden-sm hidden-md">Apr 22, 2022</td></tr><tr><td><a href="palladium.html">Palladium</a></td><td>$2145.17 <span class="hidden-sm hidden-md">oz</span></td><td class="hidden-sm hidden-md">Apr 25, 2022</td></tr><tr><td><a href="platinum.html">Platinum</a></td><td>$914.01 <span class="hidden-sm hidden-md">oz</span></td><td class="hidden-sm hidden-md">Apr 25, 2022</td></tr><tr><td><a href="silver.html">Silver</a></td><td>$23.630 <span class="hidden-sm hidden-md">oz</span></td><td class="hidden-sm hidden-md">Apr 25, 2022</td></tr><tr><td><a href="steel.html">Steel Rebar</a></td><td>$765.53 <span class="hidden-sm hidden-md">mt</span></td><td class="hidden-sm hidden-md">Apr 25, 2022</td></tr><tr><td><a href="uranium.html">Uranium</a></td><td>$56.600 <span class="hidden-sm hidden-md">lb</span></td><td class="hidden-sm hidden-md">Apr 22, 2022</td></tr><tr><td><a href="zinc.html">Zinc</a></td><td>$1.9019 <span class="hidden-sm hidden-md">lb</span></td><td class="hidden-sm hidden-md">Apr 25, 2022</td></tr></tbody>
# </table><div style="padding-left: 8px;"><a href="metalprices.php">More Metal Prices</a></div>
# </div>
# </div>
# <div class="panel panel-success">
# <div class="panel-heading"><h2 class="panel-title"><i class="fa fa-list"></i> <strong>Metal Prices &amp; Charts</strong>
# </h2></div>
# <div class="panel-body"><table class="table table-striped success table-hover table-condensed">
# <thead><tr><th>Metal Price</th><th><span class="hidden-md hidden-sm">Metal </span>Chart</th></tr></thead>
# <tbody><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=al&amp;u=lb&amp;d=20">Aluminum<span class="hidden-sm"> Price</span></a></td><td><a href="https://www.dailymetalprice.com/metalpricecharts.php?c=al&amp;u=lb&amp;d=240"><i class="fa fa-area-chart" style="color:#d1d1d1"></i><span class="hidden-md hidden-sm"> Aluminum Chart</span></a></td></tr><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=co&amp;u=lb&amp;d=20">Cobalt<span class="hidden-sm"> Price</span></a></td><td><a href="https://www.dailymetalprice.com/metalpricecharts.php?c=co&amp;u=lb&amp;d=240"><i class="fa fa-area-chart" style="color:#3333FF"></i><span class="hidden-md hidden-sm"> Cobalt Chart</span></a></td></tr><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=cu&amp;u=lb&amp;d=20">Copper<span class="hidden-sm"> Price</span></a></td><td><a href="https://www.dailymetalprice.com/metalpricecharts.php?c=cu&amp;u=lb&amp;d=240"><i class="fa fa-area-chart" style="color:#8b4500"></i><span class="hidden-md hidden-sm"> Copper Chart</span></a></td></tr><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=ga&amp;u=kg&amp;d=20">Gallium<span class="hidden-sm"> Price</span></a></td><td><a href="https://www.dailymetalprice.com/metalpricecharts.php?c=ga&amp;u=kg&amp;d=240"><i class="fa fa-area-chart" style="color:#dcdcdc"></i><span class="hidden-md hidden-sm"> Gallium Chart</span></a></td></tr><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=au&amp;u=oz&amp;d=20">Gold<span class="hidden-sm"> Price</span></a></td><td><a href="https://www.dailymetalprice.com/metalpricecharts.php?c=au&amp;u=oz&amp;d=240"><i class="fa fa-area-chart" style="color:#ffc125"></i><span class="hidden-md hidden-sm"> Gold Chart</span></a></td></tr><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=in&amp;u=kg&amp;d=20">Indium<span class="hidden-sm"> Price</span></a></td><td><a href="https://www.dailymetalprice.com/metalpricecharts.php?c=in&amp;u=kg&amp;d=240"><i class="fa fa-area-chart" style="color:#dcdcdc"></i><span class="hidden-md hidden-sm"> Indium Chart</span></a></td></tr><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=ir&amp;u=oz&amp;d=20">Iridium<span class="hidden-sm"> Price</span></a></td><td><a href="https://www.dailymetalprice.com/metalpricecharts.php?c=ir&amp;u=oz&amp;d=240"><i class="fa fa-area-chart" style="color:#bebebe"></i><span class="hidden-md hidden-sm"> Iridium Chart</span></a></td></tr><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=fe&amp;u=mt&amp;d=20">Iron Ore<span class="hidden-sm"> Price</span></a></td><td><a href="https://www.dailymetalprice.com/metalpricecharts.php?c=fe&amp;u=mt&amp;d=240"><i class="fa fa-area-chart" style="color:#cd853f"></i><span class="hidden-md hidden-sm"> Iron Ore Chart</span></a></td></tr><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=pb&amp;u=lb&amp;d=20">Lead<span class="hidden-sm"> Price</span></a></td><td><a href="https://www.dailymetalprice.com/metalpricecharts.php?c=pb&amp;u=lb&amp;d=240"><i class="fa fa-area-chart" style="color:#9e9e9e"></i><span class="hidden-md hidden-sm"> Lead Chart</span></a></td></tr><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=li&amp;u=kg&amp;d=20">Lithium<span class="hidden-sm"> Price</span></a></td><td><a href="https://www.dailymetalprice.com/metalpricecharts.php?c=li&amp;u=kg&amp;d=240"><i class="fa fa-area-chart" style="color:#dcdcdc"></i><span class="hidden-md hidden-sm"> Lithium Chart</span></a></td></tr><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=mo&amp;u=lb&amp;d=20">Molybdenum<span class="hidden-sm"> Price</span></a></td><td><a href="https://www.dailymetalprice.com/metalpricecharts.php?c=mo&amp;u=lb&amp;d=240"><i class="fa fa-area-chart" style="color:#b0c4de"></i><span class="hidden-md hidden-sm"> Molybdenum Chart</span></a></td></tr><tr><td><a href="https://www.dailymetalprice.com/metalprices.php?c=nd&amp;u=oz&amp;d= ...
# </table><div><a href="https://www.dailymetalprice.com/metalpricescurr.php">View Prices by Currency:</a><br/>
# <a href="https://www.dailymetalprice.com/metalpricescurr.php?x=USD"><i class="fa fa-usd"></i></a>
# 						<a href="https://www.dailymetalprice.com/metalpricescurr.php?x=EUR"><i class="fa fa-eur"></i></a>
# 						<a href="https://www.dailymetalprice.com/metalpricescurr.php?x=JPY"><i class="fa fa-jpy"></i></a>
# 						<a href="https://www.dailymetalprice.com/metalpricescurr.php?x=GBP"><i class="fa fa-gbp"></i></a>
# 						<a href="https://www.dailymetalprice.com/metalpricescurr.php?x=INR"><i class="fa fa-inr"></i></a>
# 						<a href="https://www.dailymetalprice.com/metalpricescurr.php?x=KRW"><i class="fa fa-krw"></i></a>
# 						<a href="https://www.dailymetalprice.com/metalpricescurr.php?x=ILS"><i class="fa fa-ils"></i></a>
# 						<a href="https://www.dailymetalprice.com/metalpricescurr.php?x=RUB"><i class="fa fa-rub"></i></a>
# 						<a href="https://www.dailymetalprice.com/metalpricescurr.php?x=BTC"><i class="fa fa-btc"></i></a>
# 						<a href="https://www.dailymetalprice.com/metalpricescurr.php?x=CNY"><strong>元</strong></a>
# 					</div>
# </div>
# </div> </div>
# <div class="col-sm-9 col-md-9 col-lg-8">
# <div class="col-md-6">
# <h1 class="h2">Daily Metal Prices</h1>
# <h2 class="h4">How are Metal Prices Determined?</h2>
# <p>Many important metals are traded on public exchanges. Among these exchanges are the
#                        New York Mercantile Commodity Exchange (COMEX) and London Metal Exchange (LME).
#                        Other metals are bought and sold directly through the offices of metal producers
#                        using prices set by those producers or related trade associations.
#                     </p>
# <p>
#                        Less common metals or those with specialized uses may not be publicly traded at all, but
#                        require direct and private agreements with the metal producer.
#                     </p>
# <p>
#                        For popular metals, many markets offer futures and options contracts which allow market
#                        participants to reduce potential volatility in the price of their metal supply.
#                        These instruments also give speculators the opportunity to profit from unpredicted price
#                        swings and volatility in metal markets.
#                     </p>
# <p>
#                        Outside of specialized commodity markets, many investment firms and equity markets offer
#                        retail investors the opportunity to participate in metal investing and price speculation
#                        through specialized instruments such as ETF's (Exchange Traded Funds). Some metal or
# 					   commodity-based ETF's may be fully backed by the material in question, while others may not.
# 					   ETF's are available for most all of the important industrial, base and precious metals.
# 					</p>
# <p>Some of the more complex metal price ETF's are designed to track the inverse of a metal's price or even
#                        multiples of the market price. Other ETF's track the price of an individual metal or a group
#                        of metals.
# 					</p>
#
# <p>Investors also participate in metal price speculation through investment in
#                        mining companies and funds that invest in mining firms.</p>
#
# <p>
#                        Our prices are daily "spot" and/or closing prices gathered from a variety of public sources
#                        and offer a daily snapshot of a particular metal's price. Metal prices may be delayed up to one business day
# 					   and may not represent actual retail rates for the metal or material in question. Please see our <a href="disclaimer.php">Privacy Policy and Disclaimer</a>.
#                     </p>
# <p>
#                        All metal prices are available in USD going back to 2000, but prices may also be available in other currencies if exchange rates are available. Our exchange rate database goes back to 2010 and is has been gathered from public sources through our sister site, <a href="https://www.foreignexchangeresource.com" target="_blank">foreignexchangeresource.com</a>. You can view current metal prices in <a href="/metalpricescurr.php">all available currencies here</a> and our <a href="/archive.php">archive of previous dates and currencies here</a>.
#                     </p>
# </div>
# <div class="col-md-6" style="margin-top: 30px">
# <div class="panel panel-success">
# <div class="panel-heading"><h2 class="panel-title"><i class="fa fa-calendar"></i> <strong>Spot Prices Updated Daily</strong>
# </h2></div>
# <div class="panel-body"><p>Updated daily. Spot prices on <strong>23 base metals, precious metals, rare metals and materials</strong> PLUS charts and historical prices going back as far as January 2000. </p><p><strong class="text-danger">NEW</strong> We've added 7 new metals and materials including: Uranium, Neodymium, Lithium, Gallium, Indium, Tellurium and Steel Rebar!</p><p><strong class="text-danger">NEW ARCHIVE</strong> We've added a <a href="/archive.php">metal price archive</a> with metal prices going back to 2000 in USD and back to 2010 in other national currencies and cryptocurrencies.</p>
# </div>
# </div>
# <div class="panel panel-success">
# <div class="panel-heading"><h2 class="panel-title"><i class="fa fa-line-chart"></i> Metal Price Charts
# </h2></div>
# <div class="panel-body"><div class="text-center">
# <h4 class="chart-title"></h4>
# <div class="sm_chart">
# <div class="chart-placeholder" id="chart"></div>
# </div>
# <div class="btn-group btn-group-xs" role="group">
# <button class="fetchSeries btn btn-default" color="#8b4500" datasrc="/ajax-single.php?c=cu&amp;k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d" type="button">Copper</button>
# <button class="fetchSeries btn btn-default" color="#d1d1d1" datasrc="/ajax-single.php?c=ni&amp;k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d" type="button">Nickel</button>
# <button class="fetchSeries btn btn-default" color="#b0c4de" datasrc="/ajax-single.php?c=zn&amp;k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d" type="button">Zinc</button>
# <button class="fetchSeries btn btn-default" color="#9e9e9e" datasrc="/ajax-single.php?c=pb&amp;k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d" type="button">Lead</button>
# <button class="fetchSeries btn btn-default hidden-xs" color="#d1d1d1" datasrc="/ajax-single.php?c=al&amp;k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d" type="button">Aluminum</button>
# <button class="fetchSeries btn btn-default" color="#cd853f" datasrc="/ajax-single.php?c=fe&amp;k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d" type="button">Iron</button>
# </div>
# <div class="btn-group btn-group-xs" role="group">
# <button class="fetchSeries btn btn-default" color="#ffc125" datasrc="/ajax-single.php?c=au&amp;k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d" type="button">Gold</button>
# <button class="fetchSeries btn btn-default" color="#dcdcdc" datasrc="/ajax-single.php?c=ag&amp;k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d" type="button">Silver</button>
# <button class="fetchSeries btn btn-default" color="#bebebe" datasrc="/ajax-single.php?c=pt&amp;k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d" type="button">Platinum</button>
# <button class="fetchSeries btn btn-default" color="#bebebe" datasrc="/ajax-single.php?c=pd&amp;k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d" type="button">Palladium</button>
# </div>
# <br/>
# </div>
# <div class="text-center"><a href="/metalpricecharts.php"><i class="fa fa-line-chart"></i>  View more metal price  charts</a></div>
# </div>
# </div>
# <div class="panel panel-success">
# <div class="panel-heading"><h2 class="panel-title"><i class="fa fa-code"></i> <strong>Widgets &amp; Charts for Websites</strong>
# </h2></div>
# <div class="panel-body"><div class="row">
# <div class="col-lg-6 col-lg-push-6">
# <p>Get <a href="/metalpricewidget.php">free metal price charts &amp; widgets for your website</a>.</p>
# <p>Display metal price tables and and daily spot price charts on your website.</p>
# <p>Our responsive widgets and charts scale to nearly any display size.</p>
# <p><a href="/metalpricewidget.php">Get the Code Here</a></p>
# </div>
# <div class="col-lg-6 col-lg-pull-6">
# <a class="text-center" href="/metalpricewidget.php">
# <img alt="Free Metal Price Charts for Websites" src="/img/xeg_chart.png.pagespeed.ic.pY5IzjFcXT.png" style="width:100%"/>
# <img alt="Free Metal Price Charts for Websites" src="/img/xeg_table.png.pagespeed.ic.UvH98647Mx.png" style="width:100%"/>
# </a>
# </div>
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# </div>
# <p> </p>
# <!-- Footer -->
# <footer>
# <nav class="navbar navbar-inverse" role="navigation">
# <div class="container-fluid" style="padding-top: 3px;">
# <div class="navbar-header">
# <!-- Mobile toggle nav button -->
# <div>
# <ul class="pull-left nav navbar-nav list-inline">
# <li><a href="/metalpricewidget.php"><i class="fa fa-code"></i> Free Metal Price Charts &amp; Widgets<span class="hidden-xs hidden-sm"> for Your Website</span></a></li>
# </ul>
# </div>
# <button class="navbar-toggle collapsed" data-target="#footer-nav" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# </div>
# <!-- Collapsible Nav links -->
# <div class="collapse navbar-collapse" id="footer-nav">
# <ul class="nav navbar-nav">
# <li><a href="disclaimer.php">Privacy Policy and Disclaimer</a></li>
# <li><a href="contact.php">Contact Us</a></li>
# </ul>
# </div>
# <!-- /.navbar-collapse -->
# </div>
# <!-- /.container-fluid -->
# </nav>
# </footer>
# <!-- End Footer -->
# <!-- Spinner Modal -->
# <div class="modal fade" id="spinner" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-body">
# <p class="text-center"><i class="fa fa-spinner fa-spin fa-3x fa-fw"></i><span class="sr-only">Loading...</span></p>
# </div>
# </div>
# </div>
# </div>
# <!-- End Modal -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js"></script>
# <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script>
# <script src="/flot,_jquery.flot.min.js+flot,_jquery.flot.time.min.js+flot,_jquery.flot.resize.min.js+js,_pym.min.js.pagespeed.jc.wZsfdIOqq5.js"></script><script>eval(mod_pagespeed_5$_ZhhRErp);</script>
# <script>eval(mod_pagespeed_oaVbyEjjW6);</script>
# <script>eval(mod_pagespeed_INrvt5Sz5N);</script>
# <script>eval(mod_pagespeed_vdBbnSKPcE);</script>
# <script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');ga('create','UA-667606-21','auto');ga('send','pageview');$(function(){var options={lines:{show:true},xaxis:{mode:"time"},grid:{borderWidth:{top:1,right:1,bottom:1,left:1}},shadowSize:0};$("button.fetchSeries").click(function(){var button=$(this);var dataurl=$(this).attr("datasrc");var color=$(this).attr("color");colors=[];colors.push(color)
# options.colors=colors;options.points={show:false};function onDataReceived(series){var data=[];data.push(series);$("h4.chart-title").text(series.comm+" One Month Chart");$.plot("#chart",data,options);}$.ajax({url:dataurl,type:"GET",dataType:"json",success:onDataReceived});});$("button.fetchSeries:first").click();$("select.fetchSeries").change(function(){var c_chart=$("#c option:selected").val();var u_chart=$("#u option:selected").val();var d_chart=$("#d option:selected").val();var color=$("#c option:selected").attr("color");colors=[];colors.push(color)
# options.colors=colors;if(d_chart<=60&&d_chart>0){options.points={show:true};}else{options.points={show:false};}var dataurl="/ajax-single.php?c="+c_chart+"&u="+u_chart+"&d="+d_chart+"&k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d";$('#spinner').modal('show');function onDataReceived(series){$('#spinner').modal('hide');var data=[];data.push(series);var d_range=$("#d option:selected").text();$("h2.chart-title").text(series.comm+" Prices");if(d_chart>0){$("h2.chart-title").append(" for the Last "+d_range);}$("a.page-link").text("http://www.dailymetalprice.com/index.php"+series.url).attr("href","http://www.dailymetalprice.com/index.php"+series.url);$("small.subtitle").text(series.label+" Chart for the Last "+d_range);$("title").text("Daily Metal Price: "+series.label+" Chart for the Last "+d_range);$('meta[name="description"]').attr("content","Daily Metal Price: "+series.label+" Chart for the Last "+d_range+". Chart daily metal price movements in multiple units.");$('link[rel="canonical"]').attr("href","http://www.dailymetalprice.com/index.php"+series.url);$.plot("#chart",data,options);}$.ajax({url:dataurl,type:"GET",dataType:"json",success:onDataReceived});});$("select.fetchRates").change(function(){var c_chart=$("#c option:selected").val();var u_chart=$("#u option:selected").val();var d_chart=$("#d option:selected").val();$('#rate-table').children().remove();$('#spinner').modal('show');var dataurl="/ajax-single.php?c="+c_chart+"&u="+u_chart+"&d="+d_chart+"&df=1&k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d";function onDataReceived(series){$('#spinner').modal('hide');var data=[];data.push(series);var d_range=$("#d option:selected").text();$("h3.rate-title").text(series.comm+" Prices for the Last "+d_range);$("#a-heading").text(series.comm+' ('+series.unit+')');$.each(series.data,function(i,val){$('#rate-table').append('<tr><td>$'+val[1]+'</td><td><span class="text-nowrap">'+val[0]+'</span></td></tr>');});$("div.table-footer").text(series.label);$("a.page-link").text("http://www.dailymetalprice.com/index.php"+series.url);$("a.page-link").attr("href","http://www.dailymetalprice.com/index.php"+series.url);$("small.subtitle").text(series.label+" for the Last "+d_range);$("title").text("Daily Metal Price: "+series.label+" for the Last "+d_range);$('meta[name="description"]').attr("content","Daily Metal Price: "+series.label+" for the Last "+d_range+". Daily metal prices for multiple metals, units and date ranges.");$('link[rel="canonical"]').attr("href","http://www.dailymetalprice.com/index.php"+series.url);}$.ajax({url:dataurl,type:"GET",dataType:"json",success:onDataReceived});});$("select.fetchDate").change(function(){var d_date=$("#d option:selected").val();if(d_date==undefined){d_date='';}$('#spinner').modal('show');$("#dateForm").submit();});$("select.fetchRatesByDate").change(function(){var d_date=$("#d option:selected").val();var x_chart=$("#x option:selected").val();if(d_date==undefined){d_date='';}if(x_chart==undefined){x_chart='';}$('#rate-table').children().remove();$('#spinner').modal('show');var dataurl="/ajax-multi.php?d="+d_date+"&x="+x_chart+"&k=f10842707b4d30b1e77a2b35f85e0c5881bf35a76fc5570efe6cd0c43a5bde1d";function onDataReceived(series){$('#spinner').modal('hide');var data=[];data.push(series);var optionExists=($('#d option[value='+d_date+']').length>0);var formatted_date;$.each(series.data,function(i,val){$('#rate-table').append('<tr><td>'+val[0]+'</td><td>'+val[1]+'<span class="hidden-xs"> '+val[4]+'</span></td><td><span class="hidden-xs">'+val[3]+' (</span>'+val[2]+'<span class="hidden-xs">)</span></td><td class="hidden-xs">'+val[5]+'</td></tr>');formatted_date=val[5];});$("h3.rate-title").text("Spot Metal Prices on "+formatted_date);if(!optionExists){$('#d').append($('<option>',{value:d_date,text:formatted_date}));}$('#d').val(d_date);$("a.page-link").text("http://www.dailymetalprice.com/index.php"+series.url);$("a.page-link").attr("href","http://www.dailymetalprice.com ...
# </body>
# </html>
